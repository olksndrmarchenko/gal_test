# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
transactions = pd.read_csv('transactions.csv')

# %%
transactions.columns
# Out:
# Index(['WEEK_END_DATE', 'STORE_NUM', 'UPC', 'UNITS', 'VISITS', 'HHS', 'SPEND',
#        'PRICE', 'BASE_PRICE', 'FEATURE', 'DISPLAY', 'TPR_ONLY'],
#       dtype='object')

# %%
transactions.rename(index = str, columns={'P'})

# %%
transactions.head(2)
# Out:
#   WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS  HHS  SPEND  PRICE  \
# 0     14-Jan-09        367  1111009477     13      13   13  18.07   1.39
# 1     14-Jan-09        367  1111009497     20      18   18  27.80   1.39
#
#    BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY
# 0        1.57        0        0         1
# 1        1.39        0        0         0

# %%
transactions.WEEK_END_DATE = pd.to_datetime(transactions.WEEK_END_DATE)

# %%
transactions.index = transactions.WEEK_END_DATE

# %%
unique_stores = transactions.STORE_NUM.unique()

# %%
unique_products = transactions.UPC.unique()

# %%
store_a_prod_a = transactions[(transactions.UPC == unique_products[3]) & (transactions.STORE_NUM == unique_stores[2])]

# %%
store_a_prod_a
# Out:
#        WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS  HHS  SPEND  PRICE  \
# 86        2009-01-14        389  1111035398      4       3    3  14.00   3.50
# 3241      2009-01-21        389  1111035398      2       2    2   6.66   3.33
# 6370      2009-01-28        389  1111035398      2       2    2   7.00   3.50
# 9499      2009-02-04        389  1111035398      7       4    4  24.50   3.50
# 12582     2009-02-11        389  1111035398      1       1    1   4.49   4.49
# 18739     2009-02-25        389  1111035398      1       1    1   4.49   4.49
# 21761     2009-03-04        389  1111035398      2       2    2   8.98   4.49
# 24776     2009-03-11        389  1111035398      2       2    2   7.98   3.99
# 27860     2009-03-18        389  1111035398      3       3    3  11.97   3.99
# 30953     2009-03-25        389  1111035398      2       2    2   7.98   3.99
# 34057     2009-04-01        389  1111035398      1       1    1   3.59   3.59
# ...

# %%
plt.plot(store_a_prod_a[['UNITS']], y =store_a_prod_a.WEEK_END_DATE)
plt.plot(store_a_prod_a['PRICE'], 'r', y = store_a_prod_a.WEEK_END_DATE)
#plt.xlabel('SPEND')
#plt.ylabel('PRICE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-5f455f2ba04d> in <module>
#       1
# ----> 2 plt.plot(store_a_prod_a[['UNITS']], y =store_a_prod_a.WEEK_END_DATE)
#       3 plt.plot(store_a_prod_a['PRICE'], 'r', y = store_a_prod_a.WEEK_END_DATE)
#       4 #plt.xlabel('SPEND')
#       5 #plt.ylabel('PRICE')
#
# ~/project/gallantra/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/project/gallantra/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
store_a_prod_a = transactions[(transactions.UPC == unique_products[3]) & (transactions.STORE_NUM == unique_stores[1])]

# %%
store_a_prod_a.index = store_a_prod_a.WEEK_END_DATE

# %%
unique_stores
# Out:
# array([  367,   387,   389,   613,   623,  2277,  2279,  2281,  2495,
#         2505,  2513,  2523,  2541,  4245,  4259,  4489,  4503,  4521,
#         6179,  6187,  6379,  6431,  8035,  8041,  8263,  9825, 10019,
#        11757, 11761, 11967, 11993, 12011, 13609, 13827, 13837, 13853,
#        13859, 15531, 15541, 15547, 15755, 15763, 15765, 17599, 17615,
#        17627, 19265, 19521, 19523, 19533, 21213, 21221, 21227, 21237,
#        21479, 21485, 23055, 23061, 23067, 23075, 23327, 23345, 23349,
#        24991, 25001, 25021, 25027, 25229, 25233, 25253, 25261, 26973,
#        26981, 26983, 27175, 28909, 29159])

# %%
stores = [transactions[(transactions.UPC == unique_products[1]) & (transactions.STORE_NUM == store_id)] for store_id in unique_stores[3:13]]

# %%
fig = plt.figure()
fig.set_size_inches(20,14)
for store in stores:
    sns.lineplot(data=store.PRICE, label='price_{}'.format(store.STORE_NUM.unique()[0]))
    sns.lineplot(data=store.UNITS, label= 'units_{}'.format(store.UPC.unique()[0]))
#sns.lineplot(data=store_a_prod_a.SPEND)

# %%
import seaborn as sns

# %%
fig = plt.figure()
fig.set_size_inches(20,12)
sns.boxplot( store_a_prod_a['PRICE'], store_a_prod_a['UNITS'])

# %%
lambda x: x.SPEND - x.BASE_PRICE * x.UNITS

# %%
transactions['STORE_NUM'].value_counts()
# Out:
# 2277     8045
# 24991    8007
# 2281     7968
# 25027    7934
# 21227    7895
# 21237    7865
# 9825     7861
# 28909    7848
# 13609    7815
# 6179     7804
# 389      7740
# 11761    7737
# 26973    7725
# 23075    7675
# 4245     7663
# 15547    7615
# 23061    7611
# 19265    7611
# 8041     7608
# 21213    7476
# 26981    7342
# 25021    7303
# 11757    7292
# 15541    7239
# 6187     7227
# 2279     7202
# 21221    7140
# 2513     7109
# 25001    7056
# 6379     7002
#          ...
# 29159    6748
# 2495     6662
# 19533    6638
# 13837    6623
# 25261    6616
# 13827    6613
# 23327    6466
# 15763    6464
# 13853    6399
# 17615    6381
# 2505     6366
# 21479    6290
# 19523    6193
# 25233    6183
# 12011    6138
# 23349    6136
# 6431     6117
# 4521     6113
# 21485    6087
# 387      6054
# 367      5946
# 17599    5880
# 2541     5801
# 25253    5732
# 10019    5477
# 15755    5391
# 2523     5258
# 11967    5104
# 23055    4723
# 8035     4119
# ...

# %%
transactions[transactions['PRICE'] > transactions['BASE_PRICE']].STORE_NUM.unique()
# Out:
# array([  613,  2277,  2279,  2505,  2513,  4489,  6187,  6431,  8041,
#        10019, 11761, 11993, 12011, 13827, 13837, 13853, 15763, 17599,
#        19265, 19523, 21221, 21227, 21485, 23075, 23349, 24991, 25001,
#        25229, 25233, 25253, 25261, 26973, 26983, 28909, 29159,  4245,
#         4259,  8035, 13609, 19521, 21213, 23061,   387,   389,  2281,
#         2495,  2523, 15541, 15765,  4521,  6179,  8263, 13859, 15755,
#        17627, 19533, 26981,   623,  6379,  9825, 17615, 21237, 23055,
#        23067, 25027,  4503, 15531, 23327, 23345, 11757, 15547, 21479,
#        27175, 11967,  2541, 25021,   367])

# %%
transactions.shape
# Out:
# (524950, 12)

# %%
result = transactions.apply(lambda x: x.SPEND - x.BASE_PRICE * x.UNITS, axis=1)

# %%
result.sum()
# Out:
# -3557214.5200000014

# %%
a = transactions.SPEND - transactions.BASE_PRICE * transactions.UNITS

# %%
a.sum()
# Out:
# -3557214.5200000014

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
check = transactions[(transactions['STORE_NUM'] == unique_stores[2]) & (check.UPC == unique_products[0])]
# Out:
# /home/olksndr/project/gallantra/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
sns.pairplot(check, kind='reg',size = 10, x_vars=['PRICE'], y_vars=['UNITS'])

# %%
transactions.columns()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a0df506e6ed3> in <module>
# ----> 1 transactions.columns()
#
# NameError: name 'transactions' is not defined

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
data = transactions[(transactions['STORE_NUM'] == 2277) & (transactions['UPC'] == 1111009477)]

# %%
data.shape
# Out:
# (156, 12)

# %%
data.head()
# Out:
#       WEEK_END_DATE  STORE_NUM         UPC  UNITS  VISITS  HHS   SPEND  PRICE  \
# 209       14-Jan-09       2277  1111009477    158     140  135  218.04   1.38
# 3367      21-Jan-09       2277  1111009477    140     119  115  193.20   1.38
# 6496      28-Jan-09       2277  1111009477    153     128  122  211.14   1.38
# 9625       4-Feb-09       2277  1111009477    183     163  157  252.54   1.38
# 12709     11-Feb-09       2277  1111009477    138     111  108  204.24   1.48
#
#        BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY
# 209          1.24        0        1         0
# 3367         1.24        0        1         0
# 6496         1.24        0        1         0
# 9625         1.24        0        1         0
# 12709        1.24        0        1         0

# %%
y = data['UNITS']

# %%
X = data.drop(['UNITS', 'SPEND'], axis=1)

# %%
X = X.reset_index().drop('index', axis = 1)

# %% [markdown]
# tscv = TimeSeriesSplit(n_splits=2)
# print(tscv)
# TimeSeriesSplit(max_train_size=None, n_splits=2)
# for train_index, test_index in tscv.split(X):
#     #print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]

# %%
X.shape
# Out:
# (156, 10)

# %%
X_train = X.iloc[0:135]
X_test = X.iloc[135:155]
y_train = y.iloc[0:135]
y_test = y.iloc[135:155]

# %%
X.index
# Out:
# RangeIndex(start=0, stop=156, step=1)

# %%
X_train['WEEK_END_DATE'] = pd.to_datetime(X_train.WEEK_END_DATE)
# Out:
# /home/olksndr/project/gallantra/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from statsmodels.formula.api import ols

# %%
x_test = X_test.drop(['STORE_NUM', 'UPC'], axis =1 )

# %%
x_test['WEEK_END_DATE'] = pd.to_datetime(x_test['WEEK_END_DATE'])

# %%
x_test = x_test.set_index('WEEK_END_DATE')

# %%
x_test.head(1)
# Out:
#                VISITS  HHS  PRICE  BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY
# WEEK_END_DATE
# 2011-08-17        158  156   1.54        1.54        0        1         0

# %%
x_train = X_train.drop(['STORE_NUM', 'UPC'], axis = 1)

# %%
x_train = x_train.set_index('WEEK_END_DATE')

# %%
x_train.head(-1)
# Out:
#                VISITS  HHS  PRICE  BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY
# WEEK_END_DATE
# 2009-01-14        140  135   1.38        1.24        0        1         0
# 2009-01-21        119  115   1.38        1.24        0        1         0
# 2009-01-28        128  122   1.38        1.24        0        1         0
# 2009-02-04        163  157   1.38        1.24        0        1         0
# 2009-02-11        111  108   1.48        1.24        0        1         0
# 2009-02-18        121  119   1.49        1.24        0        1         0
# 2009-02-25        136  132   1.49        1.24        0        1         0
# 2009-03-04        141  139   1.48        1.24        0        1         0
# 2009-03-11        125  119   1.47        1.24        0        1         0
# 2009-03-18        153  148   1.49        1.24        0        1         0
# 2009-03-25        135  129   1.49        1.24        0        1         0
# ...

# %%
y_train.index = x_train.index

# %%
df = x_train.join(y_train, how='left')

# %%
df.head()
# Out:
#                VISITS  HHS  PRICE  BASE_PRICE  FEATURE  DISPLAY  TPR_ONLY  \
# WEEK_END_DATE
# 2009-01-14        140  135   1.38        1.24        0        1         0
# 2009-01-21        119  115   1.38        1.24        0        1         0
# 2009-01-28        128  122   1.38        1.24        0        1         0
# 2009-02-04        163  157   1.38        1.24        0        1         0
# 2009-02-11        111  108   1.48        1.24        0        1         0
#
#                UNITS
# WEEK_END_DATE
# 2009-01-14       158
# 2009-01-21       140
# 2009-01-28       153
# 2009-02-04       183
# 2009-02-11       138

# %%
beef_model = ols("UNITS ~ PRICE", data=df).fit()

# %%
print(beef_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  UNITS   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     3.052
# Date:                Sun, 25 Nov 2018   Prob (F-statistic):             0.0830
# Time:                        02:02:39   Log-Likelihood:                -691.54
# No. Observations:                 135   AIC:                             1387.
# Df Residuals:                     133   BIC:                             1393.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    271.9257     59.476      4.572      0.000     154.284     389.567
# ...

# %%
beef_model.predict(x_test)
# Out:
# WEEK_END_DATE
# 2011-08-17    16.470510
# 2011-08-24    15.780861
# 2011-08-31    15.505002
# 2011-09-07    16.056721
# 2011-09-14    16.056721
# 2011-09-21    16.056721
# 2011-09-28    16.608439
# 2011-10-05    16.056721
# 2011-10-12    16.056721
# 2011-10-19    15.505002
# 2011-10-26    14.953283
# 2011-11-02    14.953283
# 2011-11-16    15.091213
# 2011-11-23    15.091213
# 2011-11-30    14.953283
# 2011-12-07    14.953283
# 2011-12-14    14.953283
# 2011-12-21    14.953283
# 2011-12-28    14.953283
# 2012-01-04    15.367072
# dtype: float64

# %%
y_test.index = x_test.index

# %%
import numpy as np

# %%
np.sqrt(np.square(y_test - beef_model.predict(x_test))) / y_test.shape[]

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # for small sample mae = 5.3783..

# %%
mean_absolute_error(beef_model.predict(x_test), y_test )
# Out:
# 54.97576128642355

# %%
beef_model.predict(x_test)
# Out:
# WEEK_END_DATE
# 2011-08-17    163.366905
# 2011-08-24    160.547195
# 2011-08-31    160.547195
# 2011-09-07    163.366905
# 2011-09-14    163.366905
# 2011-09-21    163.366905
# 2011-09-28    163.366905
# 2011-10-05    164.071833
# 2011-10-12    163.366905
# 2011-10-19    157.727485
# 2011-10-26    158.432413
# 2011-11-02    157.727485
# 2011-11-09    158.432413
# 2011-11-16    158.432413
# 2011-11-23    157.727485
# 2011-11-30    157.727485
# 2011-12-07    157.727485
# 2011-12-14    157.727485
# 2011-12-21    157.727485
# 2011-12-28    157.727485
# dtype: float64

# %%
y_test
# Out:
# 455824    178
# 459167    192
# 462509    188
# 465884    172
# 469262    269
# 472669    223
# 475966    211
# 479217    235
# 482540    178
# 485855    209
# 489139    203
# 492390    220
# 495665    232
# 499014    190
# 502338    207
# 505623    175
# 508860    203
# 512110    205
# 515393    308
# 518652    304
# Name: UNITS, dtype: int64

# %%
beef_model.predict(x_test)
# Out:
# WEEK_END_DATE
# 2011-08-17    16.470510
# 2011-08-24    15.780861
# 2011-08-31    15.505002
# 2011-09-07    16.056721
# 2011-09-14    16.056721
# 2011-09-21    16.056721
# 2011-09-28    16.608439
# 2011-10-05    16.056721
# 2011-10-12    16.056721
# 2011-10-19    15.505002
# 2011-10-26    14.953283
# 2011-11-02    14.953283
# 2011-11-16    15.091213
# 2011-11-23    15.091213
# 2011-11-30    14.953283
# 2011-12-07    14.953283
# 2011-12-14    14.953283
# 2011-12-21    14.953283
# 2011-12-28    14.953283
# 2012-01-04    15.367072
# dtype: float64

# %%
y_test.describe()
# Out:
# count    20.000000
# mean     12.450000
# std       5.041668
# min       5.000000
# 25%       9.000000
# 50%      11.500000
# 75%      15.000000
# max      22.000000
# Name: UNITS, dtype: float64

# %%
beef_model.get_prediction()

# %%
xgb.train(X_train, )
# Out:
# <module 'xgboost' from '/home/olksndr/project/gallantra/lib/python3.5/site-packages/xgboost/__init__.py'>

# %%
X_train
# Out:
#     WEEK_END_DATE  STORE_NUM         UPC  VISITS  HHS  PRICE  BASE_PRICE  \
# 0      2009-01-14        367  1111009477      13   13   1.39        1.57
# 1      2009-01-21        367  1111009477      23   23   1.39        1.57
# 2      2009-01-28        367  1111009477       7    7   1.36        1.36
# 3      2009-02-04        367  1111009477      12   12   1.38        1.38
# 4      2009-02-11        367  1111009477      14   14   1.50        1.50
# 5      2009-02-18        367  1111009477      20   20   1.49        1.49
# 6      2009-02-25        367  1111009477      11   11   1.49        1.49
# 7      2009-03-04        367  1111009477      10   10   1.49        1.49
# 8      2009-03-11        367  1111009477      12   12   1.39        1.39
# 9      2009-03-18        367  1111009477      10   10   1.48        1.48
# 10     2009-03-25        367  1111009477      12   12   1.49        1.49
# 11     2009-04-01        367  1111009477      13   13   1.49        1.49
# ...
